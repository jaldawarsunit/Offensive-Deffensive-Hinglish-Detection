# %%
# 🚀 STEP 0 — Install Required Libraries
# !pip install sentence-transformers scikit-learn pandas joblib
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\nani\anaconda3\envs\rag\lib\site-packages (5.1.2)
# Requirement already satisfied: scikit-learn in c:\users\nani\anaconda3\envs\rag\lib\site-packages (1.6.1)
# Requirement already satisfied: pandas in c:\users\nani\anaconda3\envs\rag\lib\site-packages (2.3.3)
# Requirement already satisfied: joblib in c:\users\nani\anaconda3\envs\rag\lib\site-packages (1.5.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scipy in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: networkx in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nani\anaconda3\envs\rag\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.12)

# %%
# 🚀 STEP 1 — Load Dataset
import pandas as pd

df = pd.read_csv("train.csv")

print(df.head())
print(df.label.value_counts())
# Out:
#                      text          label
# 0  Thank you so much bhai  not offensive
# 1            bhen ke lode      offensive
# 2            bh3n k3 l0d3      offensive
# 3         madarchod saale      offensive
# 4         madrch0d harami      offensive
# label
# offensive        695
# not offensive    671
# Name: count, dtype: int64

# %%
# 🚀 STEP 2 — Basic Cleaning (Minimal Needed)
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df["clean_text"] = df["text"].apply(clean_text)

# %%
# 🚀 STEP 3 — Encode Labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["label_id"] = le.fit_transform(df["label"])

le.classes_, df.head()
# Out:
# (array(['not offensive', 'offensive'], dtype=object),
#                       text          label              clean_text  label_id
#  0  Thank you so much bhai  not offensive  thank you so much bhai         0
#  1            bhen ke lode      offensive            bhen ke lode         1
#  2            bh3n k3 l0d3      offensive            bh3n k3 l0d3         1
#  3         madarchod saale      offensive         madarchod saale         1
#  4         madrch0d harami      offensive         madrch0d harami         1)

# %%
# 🚀 STEP 4 — Generate Embeddings (bge-m3 mini model)
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-small-en-v1.5")   # light + accurate

embeddings = model.encode(df["clean_text"].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/43 [00:00<?, ?it/s]

# %%
# 🚀 STEP 5 — Train SVM Classifier
from sklearn.svm import SVC

svm_model = SVC(kernel="linear", probability=True)
svm_model.fit(embeddings, df["label_id"])
# Out:
# SVC(kernel='linear', probability=True)

# %%
# 🚀 STEP 6 — Evaluate Accuracy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(
    embeddings, df["label_id"], test_size=0.2, random_state=42
)

svm_temp = SVC(kernel="linear", probability=True)
svm_temp.fit(X_train, y_train)

preds = svm_temp.predict(X_test)
acc = accuracy_score(y_test, preds)

print("Accuracy:", acc)
# Out:
# Accuracy: 0.9744525547445255

# %%
# 🚀 STEP 7 — Save Model + Label Encoder
import joblib

joblib.dump(svm_model, "svm_embeddings_model.joblib")
joblib.dump(le, "label_encoder.joblib")
model.save("embedding_model")  # saves embedding model folder

# %%
test_text = input("Enter Exapamples : ")

clean = clean_text(test_text)
embed = model.encode([clean])
pred_id = svm_model.predict(embed)[0]
pred_label = le.inverse_transform([pred_id])[0]

print("Prediction:", pred_label)
# Out:
# Enter Exapamples :  aniket bada admi hai re baba pr chutiya be hai
# Prediction: offensive
